# %%
import pandas as pd #for handling csv and csv contents
from rdflib import Graph, Literal, RDF, URIRef, Namespace #basic RDF handling
from rdflib.namespace import FOAF , XSD #most common namespaces
import urllib.parse #for parsing strings to URI's

# %%
import csv
from rdflib import Graph, Literal, Namespace, URIRef
from rdflib.namespace import DCTERMS, RDF, RDFS, SKOS, XSD

# %%
df = pd.read_csv('MatchBenar.csv')
df = df.drop('Unnamed: 0', 1)
df
# Out:
#                                           produkindo  \
# 0                         Dua Kelinci Kacang Sangrai
# 1    Dua Kelinci Kacang Polong Polongmas Ayam Bawang
# 2             Dua Kelinci Jagung Presto Bawang Putih
# 3                 Frisian Flag Susu Bubuk Full Cream
# 4              Dua Kelinci Jagung Presto Pedas Manis
# ..                                               ...
# 552                                    Buavita Guava
# 553                          Meg Keju Serbaguna 10'S
# 554           Fruitamin Minuman Coco Bit Splash Coco
# 555                                 Donald Yogu 10'S
# 556           Nutella Jam Spread Hazelnut With Cocoa
#
#                                  produsen          sertif  \
# 0                         Pt. dua kelinci  00100017571001
# 1                         Pt. dua kelinci  00100017571001
# 2                         Pt. dua kelinci  00100017571001
# 3              Pt. frisian flag indonesia  00040040520606
# ...

# %%
df['produkindo'] = df['produkindo'].replace(' ', '_', regex=True)
df['produsen'] = df['produsen'].replace(' ', '_', regex=True)
df
# Out:
#                                           produkindo  \
# 0                         Dua_Kelinci_Kacang_Sangrai
# 1    Dua_Kelinci_Kacang_Polong_Polongmas_Ayam_Bawang
# 2             Dua_Kelinci_Jagung_Presto_Bawang_Putih
# 3                 Frisian_Flag_Susu_Bubuk_Full_Cream
# 4              Dua_Kelinci_Jagung_Presto_Pedas_Manis
# ..                                               ...
# 552                                    Buavita_Guava
# 553                          Meg_Keju_Serbaguna_10'S
# 554           Fruitamin_Minuman_Coco_Bit_Splash_Coco
# 555                                 Donald_Yogu_10'S
# 556           Nutella_Jam_Spread_Hazelnut_With_Cocoa
#
#                                  produsen          sertif  \
# 0                         Pt._dua_kelinci  00100017571001
# 1                         Pt._dua_kelinci  00100017571001
# 2                         Pt._dua_kelinci  00100017571001
# 3              Pt._frisian_flag_indonesia  00040040520606
# ...

# %%
df['0'] = df['0'].str.lstrip()
df['1'] = df['1'].str.lstrip()
df['2'] = df['2'].str.lstrip()
df['3'] = df['3'].str.lstrip()
df['4'] = df['4'].str.lstrip()
df['5'] = df['5'].str.lstrip()
df['6'] = df['6'].str.lstrip()
df['7'] = df['7'].str.lstrip()
df['8'] = df['8'].str.lstrip()
df['9'] = df['9'].str.lstrip()
df['10'] = df['10'].str.lstrip()
df['11'] = df['11'].str.lstrip()
df['12'] = df['12'].str.lstrip()
df['13'] = df['13'].str.lstrip()
df['14'] = df['14'].str.lstrip()
df['15'] = df['15'].str.lstrip()
df['16'] = df['16'].str.lstrip()
df['17'] = df['17'].str.lstrip()
df['18'] = df['18'].str.lstrip()
df['19'] = df['19'].str.lstrip()
df['20'] = df['20'].str.lstrip()
df['21'] = df['21'].str.lstrip()
df['22'] = df['22'].str.lstrip()
df['23'] = df['23'].str.lstrip()
df['24'] = df['24'].str.lstrip()
df['25'] = df['25'].str.lstrip()
df['26'] = df['26'].str.lstrip()
df['27'] = df['27'].str.lstrip()
df['28'] = df['28'].str.lstrip()
df['29'] = df['29'].str.lstrip()
df['30'] = df['30'].str.lstrip()
##df['31'] = df['31'].str.lstrip()
##df['32'] = df['32'].str.lstrip()
df
# Out:
#                                           produkindo  \
# 0                         Dua_Kelinci_Kacang_Sangrai
# 1    Dua_Kelinci_Kacang_Polong_Polongmas_Ayam_Bawang
# 2             Dua_Kelinci_Jagung_Presto_Bawang_Putih
# 3                 Frisian_Flag_Susu_Bubuk_Full_Cream
# 4              Dua_Kelinci_Jagung_Presto_Pedas_Manis
# ..                                               ...
# 552                                    Buavita_Guava
# 553                          Meg_Keju_Serbaguna_10'S
# 554           Fruitamin_Minuman_Coco_Bit_Splash_Coco
# 555                                 Donald_Yogu_10'S
# 556           Nutella_Jam_Spread_Hazelnut_With_Cocoa
#
#                                  produsen          sertif  \
# 0                         Pt._dua_kelinci  00100017571001
# 1                         Pt._dua_kelinci  00100017571001
# 2                         Pt._dua_kelinci  00100017571001
# 3              Pt._frisian_flag_indonesia  00040040520606
# ...

# %%
g = Graph()
pdc = Namespace('http://example.org/product/')
loc = Namespace('http://mylocations.org/addresses/')
schema = Namespace('http://schema.org/')

# %%
##for index, row in df.iterrows():
##    g.add((URIRef(ppl+row['nama_produk']), RDF.type, FOAF.Person))
##    g.add((URIRef(ppl+row['nama_produk']), URIRef(schema+'name'), Literal(row['Name'], datatype=XSD.string) ))
##    g.add((URIRef(ppl+row['nama_produk']), FOAF.age, Literal(row['Age'], datatype=XSD.integer) ))
##    g.add((URIRef(ppl+row['nama_produk']), URIRef(schema+'address'), Literal(row['Address'], datatype=XSD.string) ))
##    g.add((URIRef(loc+urllib.parse.quote(row['Address'])), URIRef(schema+'name'), Literal(row['Address'], datatype=XSD.string) ))

# %%
for index, row in df.iterrows():
    g.add((URIRef(pdc+row['produkindo']), RDF.type, FOAF.knows))
    g.add((URIRef(pdc+row['produkindo']), URIRef('produkindo'), Literal(row['produkindo'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('sertif'), Literal(row['sertif'], datatype=XSD.integer) ))
    g.add((URIRef(pdc+row['produkindo']), URIRef('produsen'), Literal(row['produsen'], datatype=XSD.string) ))
    ##for x in range(33):
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['0'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['1'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['2'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['3'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['4'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['5'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['6'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['7'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['8'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['9'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['10'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['11'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['12'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['13'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['14'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['15'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['16'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['17'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['18'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['19'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['20'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['21'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['22'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['23'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['24'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['25'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['26'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['27'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['28'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['29'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['30'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['31'], datatype=XSD.string) ))
    g.add((URIRef(pdc+row['produkindo']),URIRef('komposisi'), Literal(row['32'], datatype=XSD.string) ))
    ##g.add((URIRef(loc+urllib.parse.quote(row['Address'])), URIRef(schema+'name'), Literal(row['Address'], datatype=XSD.string) ))

# %%
print(g.serialize(format='turtle').decode('UTF-8'))
# Out:
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://example.org/product/AL_Shifa_Natural_Honey_(Squeeze)> a <http://xmlns.com/foaf/0.1/knows> ;
#     <komposisi> "madu"^^xsd:string,
#         "nan"^^xsd:string ;
#     <produkindo> "AL_Shifa_Natural_Honey_(Squeeze)"^^xsd:string ;
#     <produsen> "Food_&amp;_fine_pastries_manufacturing_company_(sunbulah)"^^xsd:string ;
#     <sertif> 120095120419 .
#
# <http://example.org/product/Abc_Coffee_Drink_Chocomalt_Coffee> a <http://xmlns.com/foaf/0.1/knows> ;
#     <komposisi> "kosong"^^xsd:string,
#         "nan"^^xsd:string ;
#     <produkindo> "Abc_Coffee_Drink_Chocomalt_Coffee"^^xsd:string ;
#     <produsen> "Pt._santos_jaya_abadi"^^xsd:string ;
#     <sertif> 120017110901 .
#
# <http://example.org/product/Abc_Kecap_Manis_Reffil> a <http://xmlns.com/foaf/0.1/knows> ;
#     <komposisi> "air"^^xsd:string,
#         "biji gandum"^^xsd:string,
#         "garam"^^xsd:string,
#         "gula"^^xsd:string,
# ...

# %%
g.serialize('coba.ttl',format='turtle')
