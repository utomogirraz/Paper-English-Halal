# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
import nltk
nltk.download('punkt')
import re
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# import StemmerFactory and StopWordRemover
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
df = pd.read_json('Lengkap.json', encoding='latin1')
df
# Out:
#                                   nama_produk  \
# 0               Pristine 8+ Air Mineral 600Ml
# 1               Pristine 8+ Air Mineral 400Ml
# 2               Crystalline Air Mineral 600Ml
# 3              Le Minerale Air Mineral 1500Ml
# 4               Le Minerale Air Mineral 600Ml
# ...                                       ...
# 3269    Bertolli Olive Oil Extra Virgin 250mL
# 3270  Blue Band Margarine Cake & Cookie 200G
# 3271     Bertolli Olive Oil Extra Light 500mL
# 3272     Bertolli Olive Oil Extra Light 250mL
# 3273        Bertolli Olive Oil Classico 250mL
#
#                                               komposisi
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3     Calcium, magnesium, sodium, potassium, nitrate...
# 4     Calcium, magnesium, sodium, potassium, nitrate...
# ...                                                 ...
# ...

# %%
##df = df.dropna()
##df

# %%
df = df.drop_duplicates(subset=['nama_produk'], keep='last')
df
# Out:
#                                   nama_produk  \
# 0               Pristine 8+ Air Mineral 600Ml
# 1               Pristine 8+ Air Mineral 400Ml
# 2               Crystalline Air Mineral 600Ml
# 3              Le Minerale Air Mineral 1500Ml
# 4               Le Minerale Air Mineral 600Ml
# ...                                       ...
# 3269    Bertolli Olive Oil Extra Virgin 250mL
# 3270  Blue Band Margarine Cake & Cookie 200G
# 3271     Bertolli Olive Oil Extra Light 500mL
# 3272     Bertolli Olive Oil Extra Light 250mL
# 3273        Bertolli Olive Oil Classico 250mL
#
#                                               komposisi
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3     Calcium, magnesium, sodium, potassium, nitrate...
# 4     Calcium, magnesium, sodium, potassium, nitrate...
# ...                                                 ...
# ...

# %%
##df.to_csv(r'indomaretbersih.csv')

# %%
new = df["komposisi"].str.split(",", n = -1, expand = True)

# %%
new
# Out:
#                                              0           1        2   \
# 0                                          None        None     None
# 1                                          None        None     None
# 2                                          None        None     None
# 3                                       Calcium   magnesium   sodium
# 4                                       Calcium   magnesium   sodium
# ...                                         ...         ...      ...
# 3269                                       None        None     None
# 3270                                       None        None     None
# 3271  Minyak zaitun ratinasi dan minyak zaitun.        None     None
# 3272                                       None        None     None
# 3273                                       None        None     None
#
#               3         4             5         6          7     8     9   \
# ...

# %%
data = df.merge(new, how='left', on=df['komposisi'])
data
# Out:
#       key_0                        nama_produk komposisi     0     1     2  \
# 0      None      Pristine 8+ Air Mineral 600Ml      None  None  None  None
# 1      None      Pristine 8+ Air Mineral 600Ml      None  None  None  None
# 2      None      Pristine 8+ Air Mineral 600Ml      None  None  None  None
# 3      None      Pristine 8+ Air Mineral 600Ml      None  None  None  None
# 4      None      Pristine 8+ Air Mineral 600Ml      None  None  None  None
# ...     ...                                ...       ...   ...   ...   ...
# 93190  None  Bertolli Olive Oil Classico 250mL      None  None  None  None
# 93191  None  Bertolli Olive Oil Classico 250mL      None  None  None  None
# 93192  None  Bertolli Olive Oil Classico 250mL      None  None  None  None
# 93193  None  Bertolli Olive Oil Classico 250mL      None  None  None  None
# 93194  None  Bertolli Olive Oil Classico 250mL      None  None  None  None
#
# ...

# %%
data2 = data.drop_duplicates(keep='last')
data2
# Out:
#                                                    key_0  \
# 302                                                 None
# 605                                                 None
# 908                                                 None
# 910    Calcium, magnesium, sodium, potassium, nitrate...
# 912    Calcium, magnesium, sodium, potassium, nitrate...
# ...                                                  ...
# 92284                                               None
# 92587                                               None
# 92588          Minyak zaitun ratinasi dan minyak zaitun.
# 92891                                               None
# 93194                                               None
#
#                                    nama_produk  \
# 302              Pristine 8+ Air Mineral 600Ml
# 605              Pristine 8+ Air Mineral 400Ml
# 908              Crystalline Air Mineral 600Ml
# 910             Le Minerale Air Mineral 1500Ml
# ...

# %%
for i in range(33):
    data2[i] = data2[i].str.replace('[^\w\s]','')
    data2[i] = data2[i].str.replace('[0-9]','')
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\LENOVO\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data2 = data2.drop('key_0', 1)
data2
# Out:
#                                    nama_produk  \
# 302              Pristine 8+ Air Mineral 600Ml
# 605              Pristine 8+ Air Mineral 400Ml
# 908              Crystalline Air Mineral 600Ml
# 910             Le Minerale Air Mineral 1500Ml
# 912              Le Minerale Air Mineral 600Ml
# ...                                        ...
# 92284    Bertolli Olive Oil Extra Virgin 250mL
# 92587  Blue Band Margarine Cake & Cookie 200G
# 92588     Bertolli Olive Oil Extra Light 500mL
# 92891     Bertolli Olive Oil Extra Light 250mL
# 93194        Bertolli Olive Oil Classico 250mL
#
#                                                komposisi  \
# 302                                                 None
# 605                                                 None
# 908                                                 None
# 910    Calcium, magnesium, sodium, potassium, nitrate...
# 912    Calcium, magnesium, sodium, potassium, nitrate...
# ...

# %%
data2.to_csv(r'tokenlengkap.csv')
