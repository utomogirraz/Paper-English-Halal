# %%
import numpy as np
import pandas as pd

# %%
dfjaccard = pd.read_csv('Interlinking_Jaccard.csv')
dfjaccard
# Out:
#       Unnamed: 0                                    from  \
# 0              0              dua kelinci kacang sangrai
# 1              1                          ensure vanilla
# 2              2    Sarimi Goreng Rasa Ayam Kremes Isi 2
# 3              3         gery wafer roll chocolatos dark
# 4              4                             regal marie
# ...          ...                                     ...
# 1327        1425                    monde butter cookies
# 1328        1426        roma crackers malkist cappuccino
# 1329        1427          glico biscuit pocky strawberry
# 1330        1428    good time cookies chocochips classic
# 1331        1429  La Fonte Spaghetti With Mushroom Sauce
#
#                                                 URIFrom      Ingredient1  \
# 0     http://halal.addi.is.its.ac.id/foodproducts/Du...             gula
# 1     http://halal.addi.is.its.ac.id/foodproducts/En...          vitamin
# ...

# %%
dfann = pd.read_csv('Interlinking_ANN.csv')
dfann
# Out:
#       Unnamed: 0                                    from    Ingredient1_x  \
# 0              0              dua kelinci kacang sangrai             gula
# 1              1                          ensure vanilla          vitamin
# 2              2    Sarimi Goreng Rasa Ayam Kremes Isi 2     Chili Powder
# 3              3         gery wafer roll chocolatos dark  perisa sintetik
# 4              4                             regal marie         soda kue
# ...          ...                                     ...              ...
# 1327        1425        roma crackers malkist cappuccino  premiks vitamin
# 1328        1426                    monde butter cookies           vanili
# 1329        1427  La Fonte Spaghetti With Mushroom Sauce           Garlic
# 1330        1428    good time cookies chocochips classic  pewarna karamel
# 1331        1429          glico biscuit pocky strawberry     enzim papain
#
#                                                 to    Ingredient2_x  \
# ...

# %%
dfaa = pd.read_csv('Interlinking_AA.csv')
dfaa
# Out:
#       Unnamed: 0                                               from  \
# 0              0                                Chicken Noodle Soup
# 1              1  Chicken Noodle Soup With Big Chunks Of Chicken...
# 2              2                 samyang mie instant goreng extreme
# 3              3    samyang mie instant goreng pedas ayam carbonara
# 4              4                 ensure nutrition powder fos vanila
# ...          ...                                                ...
# 1274      121178                                   club air mineral
# 1275      126692                            La Fonte Elbow Macaroni
# 1276      127046                              La Fonte Sphagetti-10
# 1277      128742                    Acs Kue Sagon (Coconut Cookies)
# 1278      129222                     Tropicana Slim Nutty Chocolate
#
#                                                      to      score  \
# 0     Chicken Noodle Soup With Big Chunks Of Chicken...  13.766128
# ...

# %%
dfpa = pd.read_csv('Interlinking_PA.csv')
dfpa
# Out:
#       Unnamed: 0                              from  \
# 0             46       Indomie Mi Goreng Rasa Sate
# 1             47          Indomie Mi Instan Goreng
# 2             73       Indomie Mi Goreng Rasa Sate
# 3             74  Indomie Mi Instant Rasa Soto Mie
# 4            100      Indomie Mi Rasa Ayam Special
# ...          ...                               ...
# 1327      504371                        aqua galon
# 1328      504372                        aqua galon
# 1329      504373                        aqua galon
# 1330      504374                        aqua galon
# 1331      504375        sariwangi teh celup melati
#
#                                              to   score  LabelingAA  \
# 0                      Indomie Mi Instan Goreng  1044.0           1
# 1                   Indomie Mi Goreng Rasa Sate  1044.0           1
# 2              Indomie Mi Instant Rasa Soto Mie   972.0           1
# 3                   Indomie Mi Goreng Rasa Sate   972.0           1
# ...

# %%
dfjaccard["similarity"].mean()
# Out:
# 0.6218532849320629

# %%
dfann["similarity_x"].mean()
# Out:
# 0.6218532849320629

# %%
dfaa["score"].mean()
# Out:
# 2.803855047690903

# %%
dfpa["score"].mean()
# Out:
# 152.67717717717719
